# %%
import time
import torch
from torch import nn
import torch.nn.functional as F
from torchvision import datasets, transforms

# %%
transform = transforms.Compose([transforms.ToTensor(),
                                transforms.Normalize((0.5,), (0.5,)),
                              ])


trainset = datasets.MNIST('~/.pytorch/MNIST_data/', download=True, train=True, transform=transform)
trainloader = torch.utils.data.DataLoader(trainset, batch_size=100, shuffle=True)

testset=datasets.MNIST('~/.pytorch/MNIST_data/',download=True,train=False,transform=transform)
testloader = torch.utils.data.DataLoader(testset, batch_size=100, shuffle=False)
image,label=trainset[0]
print(len(testloader))
# Out:
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz to /root/.pytorch/MNIST_data/MNIST/raw/train-images-idx3-ubyte.gz
#   0%|          | 0/9912422 [00:00<?, ?it/s]
# Extracting /root/.pytorch/MNIST_data/MNIST/raw/train-images-idx3-ubyte.gz to /root/.pytorch/MNIST_data/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz to /root/.pytorch/MNIST_data/MNIST/raw/train-labels-idx1-ubyte.gz
#   0%|          | 0/28881 [00:00<?, ?it/s]
# Extracting /root/.pytorch/MNIST_data/MNIST/raw/train-labels-idx1-ubyte.gz to /root/.pytorch/MNIST_data/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz to /root/.pytorch/MNIST_data/MNIST/raw/t10k-images-idx3-ubyte.gz
#   0%|          | 0/1648877 [00:00<?, ?it/s]
# Extracting /root/.pytorch/MNIST_data/MNIST/raw/t10k-images-idx3-ubyte.gz to /root/.pytorch/MNIST_data/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz to /root/.pytorch/MNIST_data/MNIST/raw/t10k-labels-idx1-ubyte.gz
#   0%|          | 0/4542 [00:00<?, ?it/s]
# Extracting /root/.pytorch/MNIST_data/MNIST/raw/t10k-labels-idx1-ubyte.gz to /root/.pytorch/MNIST_data/MNIST/raw
#
# 100

# %%
class Network(nn.Module):
    def __init__(self):
        super().__init__()
        self.hidden = nn.Linear(784, 256)
        self.output = nn.Linear(256, 10)
        self.relu = nn.ReLU()
        self.softmax = nn.Softmax(dim=1)
    def forward(self, x):
        # Pass the input tensor through each of our operations
        x = x.view(-1, 28 * 28)
        x = self.hidden(x)
        x = self.relu(x)
        x = self.output(x)
        x = self.softmax(x)
        
        return x
    
start=time.time()
model=Network()
print("model parameters",model)
# Out:
# Network(
#   (hidden): Linear(in_features=784, out_features=256, bias=True)
#   (output): Linear(in_features=256, out_features=10, bias=True)
#   (relu): ReLU()
#   (softmax): Softmax(dim=1)
# )
# epoch: 1 , Training loss: 2.2833478450775146,accuracy:11.88,%
# 600
# tensor(7127)
# epoch: 2 , Training loss: 2.2834954261779785,accuracy:24.59,%
# 600
# tensor(14755)
# epoch: 3 , Training loss: 2.2472312450408936,accuracy:30.06,%
# 600
# tensor(18037)
# epoch: 4 , Training loss: 2.2099766731262207,accuracy:27.86,%
# 600
# tensor(16715)
# epoch: 5 , Training loss: 2.172919273376465,accuracy:28.34,%
# 600
# tensor(17005)
# epoch: 6 , Training loss: 2.176051378250122,accuracy:29.76,%
# 600
# tensor(17858)
# epoch: 7 , Training loss: 2.142491102218628,accuracy:31.31,%
# 600
# tensor(18784)
# epoch: 8 , Training loss: 2.0918779373168945,accuracy:36.76,%
# 600
# tensor(22054)
# epoch: 9 , Training loss: 2.036283016204834,accuracy:43.34,%
# 600
# tensor(26004)
# epoch: 10 , Training loss: 2.058967113494873,accuracy:46.75,%
# 600
# tensor(28051)
# epoch: 11 , Training loss: 2.0492727756500244,accuracy:49.89,%
# 600
# tensor(29933)
# epoch: 12 , Training loss: 2.0505483150482178,accuracy:54.44,%
# 600
# tensor(32664)
# epoch: 13 , Training loss: 1.9403642416000366,accuracy:56.40,%
# 600
# tensor(33837)
# epoch: 14 , Training loss: 1.968764066696167,accuracy:56.91,%
# 600
# tensor(34148)
# epoch: 15 , Training loss: 1.9510598182678223,accuracy:57.20,%
# 600
# tensor(34319)
# epoch: 16 , Training loss: 1.9627189636230469,accuracy:57.37,%
# 600
# tensor(34419)
# epoch: 17 , Training loss: 1.9895389080047607,accuracy:57.48,%
# 600
# tensor(34487)
# epoch: 18 , Training loss: 1.9616671800613403,accuracy:58.18,%
# 600
# tensor(34909)
# epoch: 19 , Training loss: 1.8850266933441162,accuracy:60.74,%
# 600
# tensor(36442)
# epoch: 20 , Training loss: 1.8844560384750366,accuracy:63.34,%
# 600
# tensor(38006)
# epoch: 21 , Training loss: 1.9032412767410278,accuracy:66.15,%
# 600
# tensor(39693)
# epoch: 22 , Training loss: 1.858476161956787,accuracy:68.40,%
# 600
# tensor(41038)
# epoch: 23 , Training loss: 1.829268455505371,accuracy:69.81,%
# 600
# tensor(41883)
# epoch: 24 , Training loss: 1.8387256860733032,accuracy:70.51,%
# 600
# tensor(42309)
# epoch: 25 , Training loss: 1.7617524862289429,accuracy:71.03,%
# 600
# tensor(42621)
# epoch: 26 , Training loss: 1.890783667564392,accuracy:71.38,%
# 600
# tensor(42827)
# epoch: 27 , Training loss: 1.8390815258026123,accuracy:71.69,%
# 600
# tensor(43013)
# epoch: 28 , Training loss: 1.7280950546264648,accuracy:71.96,%
# 600
# tensor(43176)
# epoch: 29 , Training loss: 1.8046189546585083,accuracy:72.16,%
# 600
# tensor(43298)
# epoch: 30 , Training loss: 1.8046669960021973,accuracy:72.33,%
# 600
# tensor(43398)

# %%
#training
learning_rate=0.001
epochs=40
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.SGD(model.parameters(), lr=learning_rate)
for e in range(epochs):
    correct=0
    for (images, labels) in (trainloader):
        optimizer.zero_grad()
        output = model(images)
        loss = criterion(output, labels)
        loss.backward()
        optimizer.step()
        _,pred=torch.max(output.data,1)
      
        #total += labels.size(0)
        correct+=(pred==labels).sum() 
    if e%5==0:
      print(f"epoch: {e+1} , Training loss: {loss.item()},accuracy:{(correct/len(trainset))*100:.2f},%")

# %%
with torch.no_grad():
    #dont calculate grad during testing
    correct = 0
    for (images, labels) in (testloader):
        output = model(images)
        _,pred=torch.max(output.data,1)
        correct+=(pred==labels).sum()
        end=time.time()
    print(f"accuracy:{(correct/len(testset))*100:.2f},%")
    print("time taken ",end-start)
# Out:
# 100
# 100
# accuracy:72.80,%
